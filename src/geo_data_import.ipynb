# %%
# !pip install geopandas
# !pip install shapely

import pandas as pd
import numpy as np


from my_modules import my_functions as mybib
from my_modules import project_functions as pr


# %load_ext autoreload
# %autoreload 2



# https://stackoverflow.com/questions/42753745/how-can-i-parse-geojson-with-python

import geopandas as gpd 

# https://www.matecdev.com/posts/point-in-polygon.html#how-to-check-if-a-point-is-inside-a-polygon-in-python
from shapely.geometry import Point, Polygon, mapping
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# path = '../data/input/geo_data/Detailnetz-Strassenabschnitte.geojson'

# with open(path, 'r', encoding='utf-8') as f:
#     geo_data = gpd.read_file(f)
    
    
# display(geo_data)

# %%
# # import geodataset 
# # https://stackoverflow.com/questions/21291725/determine-if-shapely-point-is-within-a-linestring-multilinestring 
# from tqdm import tqdm

# with open(path) as f:
#     gdf = gpd.GeoDataFrame.from_file(f)
    
# display(gdf)
# tqdm.pandas()

# test

# %%
# def linestring_to_polygon(df):
#      #LINESTRING
#     df['geometry'] = [Polygon(mapping(x)['coordinates']) for x in df.geometry]
#     return df

# linestring_to_polygon(geo_data)

# %%
path = '../data/input/geo_data/lor_planungsraeume_2021.geojson'

with open(path, 'r', encoding='utf-8') as f:
    gdf = gpd.read_file(f)
    
    
display(gdf)
# Out:
#        PLR_ID                   PLR_NAME BEZ       STAND    GROESSE_M2  \
# 0    11501341             Karlshorst Süd  11  01.01.2021  2.294022e+06
# 1    07601340   Tirschenreuther Ring Ost  07  01.01.2021  4.139693e+05
# 2    02500831                Wismarplatz  02  01.01.2021  2.489883e+05
# 3    12601134         Märkisches Zentrum  12  01.01.2021  1.127856e+06
# 4    07601547         Horstwalder Straße  07  01.01.2021  9.414340e+05
# ..        ...                        ...  ..         ...           ...
# 537  12500927              Wittenau Nord  12  01.01.2021  2.494674e+06
# 538  03200204               Blankenfelde  03  01.01.2021  1.306786e+07
# 539  10400941           Pilgramer Straße  10  01.01.2021  3.690997e+06
# 540  08100101                 Hasenheide  08  01.01.2021  8.663532e+05
# 541  11300616  Hohenschönhausener Straße  11  01.01.2021  4.169637e+05
#
#                                               geometry
# 0    MULTIPOLYGON (((400826.929 5814871.126, 400825...
# 1    MULTIPOLYGON (((387795.701 5807587.153, 387789...
# 2    MULTIPOLYGON (((396010.552 5819339.570, 396021...
# 3    MULTIPOLYGON (((387367.428 5828619.763, 387315...
# 4    MULTIPOLYGON (((391807.174 5805331.900, 391808...
# ..                                                 ...
# 537  MULTIPOLYGON (((387367.428 5828619.763, 387300...
# 538  MULTIPOLYGON (((391511.458 5829287.137, 391509...
# 539  MULTIPOLYGON (((406855.615 5816612.734, 406846...
# 540  MULTIPOLYGON (((393020.232 5815761.570, 393020...
# 541  MULTIPOLYGON (((396226.657 5822252.357, 396229...
#
# [542 rows x 6 columns]

# %%
# https://stackoverflow.com/questions/20474549/extract-points-coordinates-from-a-polygon-in-shapely


gdf['coordinates'] = gdf['geometry'].apply(lambda geom: list(geometry.exterior.coords))
gdf['GROESSE_M2'] = gdf['GROESSE_M2'].apply(lambda x: round(x,2))

gdf.columns = ['lor_id', 'sub_district_name', 'district_id', 'last_updated', 'area_in_sqm', 'geometry', 'coordinates']

gdf
# Out:
#        lor_id          sub_district_name district_id last_updated  \
# 0    11501341             Karlshorst Süd          11   01.01.2021
# 1    07601340   Tirschenreuther Ring Ost          07   01.01.2021
# 2    02500831                Wismarplatz          02   01.01.2021
# 3    12601134         Märkisches Zentrum          12   01.01.2021
# 4    07601547         Horstwalder Straße          07   01.01.2021
# ..        ...                        ...         ...          ...
# 537  12500927              Wittenau Nord          12   01.01.2021
# 538  03200204               Blankenfelde          03   01.01.2021
# 539  10400941           Pilgramer Straße          10   01.01.2021
# 540  08100101                 Hasenheide          08   01.01.2021
# 541  11300616  Hohenschönhausener Straße          11   01.01.2021
#
#      area_in_sqm                                           geometry  \
# 0     2294021.72  MULTIPOLYGON (((400826.929 5814871.126, 400825...
# 1      413969.33  MULTIPOLYGON (((387795.701 5807587.153, 387789...
# 2      248988.29  MULTIPOLYGON (((396010.552 5819339.570, 396021...
# 3     1127855.84  MULTIPOLYGON (((387367.428 5828619.763, 387315...
# 4      941433.95  MULTIPOLYGON (((391807.174 5805331.900, 391808...
# ..           ...                                                ...
# 537   2494674.42  MULTIPOLYGON (((387367.428 5828619.763, 387300...
# 538  13067860.48  MULTIPOLYGON (((391511.458 5829287.137, 391509...
# 539   3690997.15  MULTIPOLYGON (((406855.615 5816612.734, 406846...
# 540    866353.17  MULTIPOLYGON (((393020.232 5815761.570, 393020...
# 541    416963.69  MULTIPOLYGON (((396226.657 5822252.357, 396229...
#
#                                            coordinates
# 0    [(13.143689780258327, 52.397464458522585), (13...
# 1    [(13.143689780258327, 52.397464458522585), (13...
# 2    [(13.143689780258327, 52.397464458522585), (13...
# 3    [(13.143689780258327, 52.397464458522585), (13...
# 4    [(13.143689780258327, 52.397464458522585), (13...
# ..                                                 ...
# 537  [(13.143689780258327, 52.397464458522585), (13...
# 538  [(13.143689780258327, 52.397464458522585), (13...
# 539  [(13.143689780258327, 52.397464458522585), (13...
# 540  [(13.143689780258327, 52.397464458522585), (13...
# 541  [(13.143689780258327, 52.397464458522585), (13...
#
# [542 rows x 7 columns]

# %%
gdf.to_excel('../data/output/planungsraume.xlsx')
gdf.to_pickle('../data/output/planungsraume.pkl')
gdf.to_csv('../data/output/planungsraume.csv', index=True)
